# %%
import pandas as pd
import numpy as np

# %%
#Read CSV and Create dataframe
file = 'cleandataETL.csv'
df = pd.read_csv(file)
df.head()
# Out:
#                 Player  Year Start  Year Ended Position Height  Weight  \
# 0       Alaa Abdelnaby        1991        1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969        1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970        1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991        2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998        2003        F    6-6   223.0
#
#           Birth Day                                College  Games Played  \
# 0     June 24, 1968                        Duke University         385.0
# 1     April 7, 1946                  Iowa State University         570.0
# 2    April 16, 1947  University of California, Los Angeles        1560.0
# 3     March 9, 1969             Louisiana State University         586.0
# 4  November 3, 1974              San Jose State University         321.0
#
#    Shots Made  Shots Attempted  Total Rebounds  Assist  Steals  Blocks  \
# ...

# %%
#Analysis of data i.e correlations 
df.corr(method='pearson')
# Out:
#                  Year Start  Year Ended    Weight  Games Played  Shots Made  \
# Year Start         1.000000    0.974565  0.316316      0.010819   -0.030309
# Year Ended         0.974565    1.000000  0.324659      0.213414    0.146974
# Weight             0.316316    0.324659  1.000000      0.053869    0.030048
# Games Played       0.010819    0.213414  0.053869      1.000000    0.885171
# Shots Made        -0.030309    0.146974  0.030048      0.885171    1.000000
# Shots Attempted   -0.042218    0.136752  0.007314      0.891661    0.994993
# Total Rebounds    -0.051735    0.115909  0.221079      0.821902    0.835973
# Assist            -0.017746    0.133999 -0.173491      0.764508    0.796722
# Steals             0.146511    0.302594 -0.048981      0.800306    0.784674
# Blocks             0.102872    0.219166  0.261374      0.587557    0.547992
# Points            -0.024544    0.152754  0.024621      0.883575    0.996850
#
# ...
